# %% [markdown]
# # Programming Assignment
#
# ## Saving and loading models, with application to the EuroSat dataset
#
# ### Instructions
#
# In this notebook, you will create a neural network that classifies land uses and land covers from satellite imagery. You will save your model using Tensorflow's callbacks and reload it later. You will also load in a pre-trained neural network classifier and compare performance with it.
#
# Some code cells are provided for you in the notebook. You should avoid editing provided code, and make sure to execute the cells in order to avoid unexpected errors. Some cells begin with the line:
#
# `#### GRADED CELL ####`
#
# Don't move or edit this first line - this is what the automatic grader looks for to recognise graded cells. These cells require you to write your own code to complete them, and are automatically graded when you submit the notebook. Don't edit the function name or signature provided in these cells, otherwise the automatic grader might not function properly. Inside these graded cells, you can use any functions or classes that are imported below, but make sure you don't use any variables that are outside the scope of the function.
#
# ### How to submit
#
# Complete all the tasks you are asked for in the worksheet. When you have finished and are happy with your code, press the **Submit Assignment** button at the top of this notebook.
#
# ### Let's get started!
#
# We'll start running some imports, and loading the dataset. Do not edit the existing imports in the following cell. If you would like to make further Tensorflow imports, you should add them here.

# %%
#### PACKAGE IMPORTS ####

# Run this cell first to import all required packages. Do not make any imports elsewhere in the notebook

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import numpy as np
import pandas as pd

# If you would like to make further imports from tensorflow, add them here

# %% [markdown]
# ![EuroSAT overview image](data/eurosat_overview.jpg)
#
# #### The EuroSAT dataset
#
# In this assignment, you will use the [EuroSAT dataset](https://github.com/phelber/EuroSAT). It consists of 27000 labelled Sentinel-2 satellite images of different land uses: residential, industrial, highway, river, forest, pasture, herbaceous vegetation, annual crop, permanent crop and sea/lake. For a reference, see the following papers:
# - Eurosat: A novel dataset and deep learning benchmark for land use and land cover classification. Patrick Helber, Benjamin Bischke, Andreas Dengel, Damian Borth. IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing, 2019.
# - Introducing EuroSAT: A Novel Dataset and Deep Learning Benchmark for Land Use and Land Cover Classification. Patrick Helber, Benjamin Bischke, Andreas Dengel. 2018 IEEE International Geoscience and Remote Sensing Symposium, 2018.
#
# Your goal is to construct a neural network that classifies a satellite image into one of these 10 classes, as well as applying some of the saving and loading techniques you have learned in the previous sessions.

# %% [markdown]
# #### Import the data
#
# The dataset you will train your model on is a subset of the total data, with 4000 training images and 1000 testing images, with roughly equal numbers of each class. The code to import the data is provided below.

# %%
# Run this cell to import the Eurosat data

def load_eurosat_data():
    data_dir = 'data/'
    x_train = np.load(os.path.join(data_dir, 'x_train.npy'))
    y_train = np.load(os.path.join(data_dir, 'y_train.npy'))
    x_test  = np.load(os.path.join(data_dir, 'x_test.npy'))
    y_test  = np.load(os.path.join(data_dir, 'y_test.npy'))
    return (x_train, y_train), (x_test, y_test)

(x_train, y_train), (x_test, y_test) = load_eurosat_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# You can now construct a model to fit to the data. Using the Sequential API, build your model according to the following specifications:
#
# * The model should use the input_shape in the function argument to set the input size in the first layer.
# * The first layer should be a Conv2D layer with 16 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_1'.
# * The second layer should also be a Conv2D layer with 8 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_2'.
# * The third layer should be a MaxPooling2D layer with a pooling window size of 8x8. Name this layer 'pool_1'.
# * The fourth layer should be a Flatten layer, named 'flatten'.
# * The fifth layer should be a Dense layer with 32 units, a ReLU activation. Name this layer 'dense_1'.
# * The sixth and final layer should be a Dense layer with 10 units and softmax activation. Name this layer 'dense_2'.
#
# In total, the network should have 6 layers.

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_new_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should also compile the model with the Adam optimiser, sparse categorical cross
    entropy loss function, and a single accuracy metric.
    """
    model = Sequential([
        Conv2D(16, kernel_size=3, activation='relu', input_shape=input_shape, padding='SAME', name='conv_1'),
        Conv2D(8, kernel_size=3, activation='relu', padding='SAME', name='conv_2'),
        MaxPooling2D(8, name='pool_1'),
        Flatten(name='flatten'),
        Dense(32, activation='relu', name='dense_1'),
        Dense(10, activation='softmax', name='dense_2')
    ])
    
    model.compile(
        optimizer='adam',
        loss = 'sparse_categorical_crossentropy',
        metrics = ['accuracy']
    )
    
    return model

# %% [markdown]
# #### Compile and evaluate the model

# %%
# Run your function to create the model

model = get_new_model(x_train[0].shape)

# %%
# Run this cell to define a function to evaluate a model's test accuracy

def get_test_accuracy(model, x_test, y_test):
    """Test model classification accuracy"""
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
# Print the model summary and calculate its initialised test accuracy

model.summary()
get_test_accuracy(model, x_test, y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 8)         1160
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 8, 8, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                16416
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 18,354
# Trainable params: 18,354
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.106

# %% [markdown]
# #### Create checkpoints to save model during training, with a criterion
#
# You will now create three callbacks:
# - `checkpoint_every_epoch`: checkpoint that saves the model weights every epoch during training
# - `checkpoint_best_only`: checkpoint that saves only the weights with the highest validation accuracy. Use the testing data as the validation data.
# - `early_stopping`: early stopping object that ends training if the validation accuracy has not improved in 3 epochs.

# %%
#### GRADED CELL ####

# Complete the following functions. 
# Make sure to not change the function names or arguments.

def get_checkpoint_every_epoch():
    """
    This function should return a ModelCheckpoint object that:
    - saves the weights only at the end of every epoch
    - saves into a directory called 'checkpoints_every_epoch' inside the current working directory
    - generates filenames in that directory like 'checkpoint_XXX' where
      XXX is the epoch number formatted to have three digits, e.g. 001, 002, 003, etc.
    """
    checkpoints_every_epoch = 'model_checkpoint/checkpoints'
    checkpoints_epoch = ModelCheckpoint(filepath=checkpoints_every_epoch,
                                       save_weights_only = True,
                                       frequency = 'epoch',
                                       verbose=1)
    return checkpoints_epoch
    
    


def get_checkpoint_best_only():
    """
    This function should return a ModelCheckpoint object that:
    - saves only the weights that generate the highest validation (testing) accuracy
    - saves into a directory called 'checkpoints_best_only' inside the current working directory
    - generates a file called 'checkpoints_best_only/checkpoint' 
    """
    checkpoints_best_only = 'model_checkpoint_best/checkpoints'
    checkpoints_best = ModelCheckpoint(filepath=checkpoints_best_only,
                                      save_weights_only = True,
                                      save_freq = 'epoch',
                                      monitor = 'val_accuracy',
                                      save_best_only = True, 
                                      verbose = 1)
    return checkpoints_best

# %%
#### GRADED CELL ####

# Complete the following function. 
# Make sure to not change the function name or arguments.

def get_early_stopping():
    """
    This function should return an EarlyStopping callback that stops training when
    the validation (testing) accuracy has not improved in the last 3 epochs.
    HINT: use the EarlyStopping callback with the correct 'monitor' and 'patience'
    """
    callbacks = tf.keras.callbacks.EarlyStopping(patience=30, monitor='val_accuracy')
    return callbacks

# %%
# Run this cell to create the callbacks

checkpoint_every_epoch = get_checkpoint_every_epoch()
checkpoint_best_only = get_checkpoint_best_only()
early_stopping = get_early_stopping()

# %% [markdown]
# #### Train model using the callbacks
#
# Now, you will train the model using the three callbacks you created. If you created the callbacks correctly, three things should happen:
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_every_epoch`
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_best_only` **only** if those weights lead to the highest test accuracy
# - Training stops when the testing accuracy has not improved in three epochs.
#
# You should then have two directories:
# - A directory called `checkpoints_every_epoch` containing filenames that include `checkpoint_001`, `checkpoint_002`, etc with the `001`, `002` corresponding to the epoch
# - A directory called `checkpoints_best_only` containing filenames that include `checkpoint`, which contain only the weights leading to the highest testing accuracy

# %%
# Train model using the callbacks you just created

callbacks = [checkpoint_every_epoch, checkpoint_best_only, early_stopping]
model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=callbacks)
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.9444 - accuracy: 0.2634
# Epoch 00001: saving model to model_checkpoint/checkpoints
#
# Epoch 00001: val_accuracy improved from -inf to 0.34600, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 82s 21ms/sample - loss: 1.9404 - accuracy: 0.2645 - val_loss: 1.5938 - val_accuracy: 0.3460
# Epoch 2/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.4321 - accuracy: 0.4582
# Epoch 00002: saving model to model_checkpoint/checkpoints
#
# Epoch 00002: val_accuracy improved from 0.34600 to 0.45700, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 1.4320 - accuracy: 0.4582 - val_loss: 1.3876 - val_accuracy: 0.4570
# Epoch 3/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.2942 - accuracy: 0.5252
# Epoch 00003: saving model to model_checkpoint/checkpoints
#
# Epoch 00003: val_accuracy improved from 0.45700 to 0.52400, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 1.2933 - accuracy: 0.5260 - val_loss: 1.2675 - val_accuracy: 0.5240
# Epoch 4/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.2124 - accuracy: 0.5512
# Epoch 00004: saving model to model_checkpoint/checkpoints
#
# Epoch 00004: val_accuracy improved from 0.52400 to 0.52500, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 1.2121 - accuracy: 0.5505 - val_loss: 1.2268 - val_accuracy: 0.5250
# Epoch 5/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.1376 - accuracy: 0.5789
# Epoch 00005: saving model to model_checkpoint/checkpoints
#
# Epoch 00005: val_accuracy improved from 0.52500 to 0.57600, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 82s 21ms/sample - loss: 1.1393 - accuracy: 0.5788 - val_loss: 1.1584 - val_accuracy: 0.5760
# Epoch 6/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0959 - accuracy: 0.6043
# Epoch 00006: saving model to model_checkpoint/checkpoints
#
# Epoch 00006: val_accuracy did not improve from 0.57600
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 1.0958 - accuracy: 0.6043 - val_loss: 1.1664 - val_accuracy: 0.5450
# Epoch 7/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0421 - accuracy: 0.6172
# Epoch 00007: saving model to model_checkpoint/checkpoints
#
# Epoch 00007: val_accuracy improved from 0.57600 to 0.59500, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 1.0426 - accuracy: 0.6160 - val_loss: 1.0691 - val_accuracy: 0.5950
# Epoch 8/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9890 - accuracy: 0.6474
# Epoch 00008: saving model to model_checkpoint/checkpoints
#
# Epoch 00008: val_accuracy improved from 0.59500 to 0.61800, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.9915 - accuracy: 0.6460 - val_loss: 1.0565 - val_accuracy: 0.6180
# Epoch 9/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9537 - accuracy: 0.6641
# Epoch 00009: saving model to model_checkpoint/checkpoints
#
# Epoch 00009: val_accuracy improved from 0.61800 to 0.64300, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.9534 - accuracy: 0.6643 - val_loss: 0.9761 - val_accuracy: 0.6430
# Epoch 10/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9029 - accuracy: 0.6789
# Epoch 00010: saving model to model_checkpoint/checkpoints
#
# Epoch 00010: val_accuracy did not improve from 0.64300
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.9022 - accuracy: 0.6790 - val_loss: 0.9826 - val_accuracy: 0.6410
# Epoch 11/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8979 - accuracy: 0.6767
# Epoch 00011: saving model to model_checkpoint/checkpoints
#
# Epoch 00011: val_accuracy improved from 0.64300 to 0.66800, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 86s 21ms/sample - loss: 0.8985 - accuracy: 0.6758 - val_loss: 0.9401 - val_accuracy: 0.6680
# Epoch 12/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8408 - accuracy: 0.7094
# Epoch 00012: saving model to model_checkpoint/checkpoints
#
# Epoch 00012: val_accuracy did not improve from 0.66800
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.8418 - accuracy: 0.7088 - val_loss: 0.9332 - val_accuracy: 0.6650
# Epoch 13/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8137 - accuracy: 0.7152
# Epoch 00013: saving model to model_checkpoint/checkpoints
#
# Epoch 00013: val_accuracy improved from 0.66800 to 0.67200, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.8110 - accuracy: 0.7163 - val_loss: 0.9148 - val_accuracy: 0.6720
# Epoch 14/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7936 - accuracy: 0.7210
# Epoch 00014: saving model to model_checkpoint/checkpoints
#
# Epoch 00014: val_accuracy improved from 0.67200 to 0.68300, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 84s 21ms/sample - loss: 0.7939 - accuracy: 0.7203 - val_loss: 0.8491 - val_accuracy: 0.6830
# Epoch 15/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7782 - accuracy: 0.7205
# Epoch 00015: saving model to model_checkpoint/checkpoints
#
# Epoch 00015: val_accuracy did not improve from 0.68300
# 4000/4000 [==============================] - 82s 21ms/sample - loss: 0.7774 - accuracy: 0.7207 - val_loss: 0.9430 - val_accuracy: 0.6610
# Epoch 16/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7658 - accuracy: 0.7243
# Epoch 00016: saving model to model_checkpoint/checkpoints
#
# Epoch 00016: val_accuracy improved from 0.68300 to 0.68800, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 84s 21ms/sample - loss: 0.7645 - accuracy: 0.7247 - val_loss: 0.8649 - val_accuracy: 0.6880
# Epoch 17/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7368 - accuracy: 0.7394
# Epoch 00017: saving model to model_checkpoint/checkpoints
#
# Epoch 00017: val_accuracy improved from 0.68800 to 0.69500, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.7381 - accuracy: 0.7398 - val_loss: 0.8235 - val_accuracy: 0.6950
# Epoch 18/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7185 - accuracy: 0.7477
# Epoch 00018: saving model to model_checkpoint/checkpoints
#
# Epoch 00018: val_accuracy improved from 0.69500 to 0.70200, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.7182 - accuracy: 0.7483 - val_loss: 0.8158 - val_accuracy: 0.7020
# Epoch 19/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6936 - accuracy: 0.7545
# Epoch 00019: saving model to model_checkpoint/checkpoints
#
# Epoch 00019: val_accuracy improved from 0.70200 to 0.71300, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.6933 - accuracy: 0.7550 - val_loss: 0.8066 - val_accuracy: 0.7130
# Epoch 20/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6926 - accuracy: 0.7543
# Epoch 00020: saving model to model_checkpoint/checkpoints
#
# Epoch 00020: val_accuracy did not improve from 0.71300
# 4000/4000 [==============================] - 82s 21ms/sample - loss: 0.6918 - accuracy: 0.7548 - val_loss: 0.8031 - val_accuracy: 0.6990
# Epoch 21/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6632 - accuracy: 0.7659
# Epoch 00021: saving model to model_checkpoint/checkpoints
#
# Epoch 00021: val_accuracy improved from 0.71300 to 0.71700, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.6626 - accuracy: 0.7657 - val_loss: 0.8085 - val_accuracy: 0.7170
# Epoch 22/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6674 - accuracy: 0.7571
# Epoch 00022: saving model to model_checkpoint/checkpoints
#
# Epoch 00022: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 84s 21ms/sample - loss: 0.6675 - accuracy: 0.7575 - val_loss: 0.8346 - val_accuracy: 0.7000
# Epoch 23/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6393 - accuracy: 0.7704
# Epoch 00023: saving model to model_checkpoint/checkpoints
#
# Epoch 00023: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.6378 - accuracy: 0.7705 - val_loss: 0.7993 - val_accuracy: 0.7090
# Epoch 24/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6507 - accuracy: 0.7601
# Epoch 00024: saving model to model_checkpoint/checkpoints
#
# Epoch 00024: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 82s 20ms/sample - loss: 0.6502 - accuracy: 0.7600 - val_loss: 0.7947 - val_accuracy: 0.7130
# Epoch 25/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6269 - accuracy: 0.7755
# Epoch 00025: saving model to model_checkpoint/checkpoints
#
# Epoch 00025: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 82s 20ms/sample - loss: 0.6268 - accuracy: 0.7753 - val_loss: 0.8665 - val_accuracy: 0.6940
# Epoch 26/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6135 - accuracy: 0.7742
# Epoch 00026: saving model to model_checkpoint/checkpoints
#
# Epoch 00026: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 82s 21ms/sample - loss: 0.6154 - accuracy: 0.7732 - val_loss: 0.8237 - val_accuracy: 0.7050
# Epoch 27/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5859 - accuracy: 0.7876
# Epoch 00027: saving model to model_checkpoint/checkpoints
#
# Epoch 00027: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.5884 - accuracy: 0.7868 - val_loss: 0.8074 - val_accuracy: 0.7100
# Epoch 28/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6097 - accuracy: 0.7823
# Epoch 00028: saving model to model_checkpoint/checkpoints
#
# Epoch 00028: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 0.6113 - accuracy: 0.7820 - val_loss: 0.9698 - val_accuracy: 0.6700
# Epoch 29/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5767 - accuracy: 0.7961
# Epoch 00029: saving model to model_checkpoint/checkpoints
#
# Epoch 00029: val_accuracy did not improve from 0.71700
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.5769 - accuracy: 0.7960 - val_loss: 0.7967 - val_accuracy: 0.7140
# Epoch 30/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5814 - accuracy: 0.7865
# Epoch 00030: saving model to model_checkpoint/checkpoints
#
# Epoch 00030: val_accuracy improved from 0.71700 to 0.72500, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 82s 21ms/sample - loss: 0.5807 - accuracy: 0.7872 - val_loss: 0.8137 - val_accuracy: 0.7250
# Epoch 31/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5764 - accuracy: 0.7933
# Epoch 00031: saving model to model_checkpoint/checkpoints
#
# Epoch 00031: val_accuracy did not improve from 0.72500
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.5750 - accuracy: 0.7940 - val_loss: 0.7612 - val_accuracy: 0.7120
# Epoch 32/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5384 - accuracy: 0.8052
# Epoch 00032: saving model to model_checkpoint/checkpoints
#
# Epoch 00032: val_accuracy improved from 0.72500 to 0.72700, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 0.5396 - accuracy: 0.8050 - val_loss: 0.7559 - val_accuracy: 0.7270
# Epoch 33/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5158 - accuracy: 0.8140
# Epoch 00033: saving model to model_checkpoint/checkpoints
#
# Epoch 00033: val_accuracy improved from 0.72700 to 0.74400, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.5167 - accuracy: 0.8133 - val_loss: 0.7453 - val_accuracy: 0.7440
# Epoch 34/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.8208
# Epoch 00034: saving model to model_checkpoint/checkpoints
#
# Epoch 00034: val_accuracy did not improve from 0.74400
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.4968 - accuracy: 0.8210 - val_loss: 0.7907 - val_accuracy: 0.7240
# Epoch 35/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4866 - accuracy: 0.8206
# Epoch 00035: saving model to model_checkpoint/checkpoints
#
# Epoch 00035: val_accuracy did not improve from 0.74400
# 4000/4000 [==============================] - 82s 20ms/sample - loss: 0.4872 - accuracy: 0.8200 - val_loss: 0.7778 - val_accuracy: 0.7380
# Epoch 36/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4833 - accuracy: 0.8251
# Epoch 00036: saving model to model_checkpoint/checkpoints
#
# Epoch 00036: val_accuracy improved from 0.74400 to 0.75400, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 82s 20ms/sample - loss: 0.4836 - accuracy: 0.8250 - val_loss: 0.7617 - val_accuracy: 0.7540
# Epoch 37/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5073 - accuracy: 0.8160
# Epoch 00037: saving model to model_checkpoint/checkpoints
#
# Epoch 00037: val_accuracy did not improve from 0.75400
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.5056 - accuracy: 0.8167 - val_loss: 0.7949 - val_accuracy: 0.7330
# Epoch 38/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4644 - accuracy: 0.8296
# Epoch 00038: saving model to model_checkpoint/checkpoints
#
# Epoch 00038: val_accuracy did not improve from 0.75400
# 4000/4000 [==============================] - 82s 20ms/sample - loss: 0.4653 - accuracy: 0.8298 - val_loss: 0.7932 - val_accuracy: 0.7350
# Epoch 39/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4459 - accuracy: 0.8435
# Epoch 00039: saving model to model_checkpoint/checkpoints
#
# Epoch 00039: val_accuracy did not improve from 0.75400
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.4450 - accuracy: 0.8440 - val_loss: 0.7467 - val_accuracy: 0.7430
# Epoch 40/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4220 - accuracy: 0.8528
# Epoch 00040: saving model to model_checkpoint/checkpoints
#
# Epoch 00040: val_accuracy did not improve from 0.75400
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 0.4222 - accuracy: 0.8528 - val_loss: 0.7575 - val_accuracy: 0.7370
# Epoch 41/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4164 - accuracy: 0.8513
# Epoch 00041: saving model to model_checkpoint/checkpoints
#
# Epoch 00041: val_accuracy did not improve from 0.75400
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 0.4172 - accuracy: 0.8512 - val_loss: 0.7577 - val_accuracy: 0.7420
# Epoch 42/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4167 - accuracy: 0.8516
# Epoch 00042: saving model to model_checkpoint/checkpoints
#
# Epoch 00042: val_accuracy did not improve from 0.75400
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 0.4151 - accuracy: 0.8525 - val_loss: 0.7964 - val_accuracy: 0.7300
# Epoch 43/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4065 - accuracy: 0.8556
# Epoch 00043: saving model to model_checkpoint/checkpoints
#
# Epoch 00043: val_accuracy improved from 0.75400 to 0.75500, saving model to model_checkpoint_best/checkpoints
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.4057 - accuracy: 0.8558 - val_loss: 0.7763 - val_accuracy: 0.7550
# Epoch 44/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.4074 - accuracy: 0.8596
# Epoch 00044: saving model to model_checkpoint/checkpoints
#
# Epoch 00044: val_accuracy did not improve from 0.75500
# 4000/4000 [==============================] - 80s 20ms/sample - loss: 0.4057 - accuracy: 0.8602 - val_loss: 0.8013 - val_accuracy: 0.7300
# Epoch 45/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3925 - accuracy: 0.8571
# Epoch 00045: saving model to model_checkpoint/checkpoints
#
# Epoch 00045: val_accuracy did not improve from 0.75500
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.3937 - accuracy: 0.8568 - val_loss: 0.7784 - val_accuracy: 0.7340
# Epoch 46/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3858 - accuracy: 0.8616
# Epoch 00046: saving model to model_checkpoint/checkpoints
#
# Epoch 00046: val_accuracy did not improve from 0.75500
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.3862 - accuracy: 0.8615 - val_loss: 0.7956 - val_accuracy: 0.7320
# Epoch 47/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3578 - accuracy: 0.8755
# Epoch 00047: saving model to model_checkpoint/checkpoints
#
# Epoch 00047: val_accuracy did not improve from 0.75500
# 4000/4000 [==============================] - 82s 20ms/sample - loss: 0.3601 - accuracy: 0.8748 - val_loss: 0.8596 - val_accuracy: 0.7380
# Epoch 48/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3700 - accuracy: 0.8692
# Epoch 00048: saving model to model_checkpoint/checkpoints
#
# Epoch 00048: val_accuracy did not improve from 0.75500
# 4000/4000 [==============================] - 82s 20ms/sample - loss: 0.3700 - accuracy: 0.8692 - val_loss: 0.7746 - val_accuracy: 0.7380
# Epoch 49/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3564 - accuracy: 0.8717
# Epoch 00049: saving model to model_checkpoint/checkpoints
#
# Epoch 00049: val_accuracy did not improve from 0.75500
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.3553 - accuracy: 0.8723 - val_loss: 0.8069 - val_accuracy: 0.7500
# Epoch 50/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.3608 - accuracy: 0.8700
# Epoch 00050: saving model to model_checkpoint/checkpoints
#
# Epoch 00050: val_accuracy did not improve from 0.75500
# 4000/4000 [==============================] - 81s 20ms/sample - loss: 0.3599 - accuracy: 0.8698 - val_loss: 0.8409 - val_accuracy: 0.7360

# %% [markdown]
# #### Create new instance of model and load on both sets of weights
#
# Now you will use the weights you just saved in a fresh model. You should create two functions, both of which take a freshly instantiated model instance:
# - `model_last_epoch` should contain the weights from the latest saved epoch
# - `model_best_epoch` should contain the weights from the saved epoch with the highest testing accuracy
#
# _Hint: use the_ `tf.train.latest_checkpoint` _function to get the filename of the latest saved checkpoint file. Check the docs_ [_here_](https://www.tensorflow.org/api_docs/python/tf/train/latest_checkpoint).

# %%
#### GRADED CELL ####

# Complete the following functions. 
# Make sure to not change the function name or arguments.

def get_model_last_epoch(model):
    """
    This function should create a new instance of the CNN you created earlier,
    load on the weights from the last training epoch, and return this model.
    """
    model_last_epoch = tf.train.latest_checkpoint('model_checkpoint/checkpoints')
    
    
    
def get_model_best_epoch(model):
    """
    This function should create a new instance of the CNN you created earlier, load 
    on the weights leading to the highest validation accuracy, and return this model.
    """
    model_best_path = tf.train.latest_checkpoint('model_checkpoint_best/checkpoints')

# %%
# Run this cell to create two models: one with the weights from the last training
# epoch, and one with the weights leading to the highest validation (testing) accuracy.
# Verify that the second has a higher validation (testing) accuarcy.

model_last_epoch = get_model_last_epoch(get_new_model(x_train[0].shape))
model_best_epoch = get_model_best_epoch(get_new_model(x_train[0].shape))
print('Model with last epoch weights:')
get_test_accuracy(model_last_epoch, x_test, y_test)
print('')
print('Model with best epoch weights:')
get_test_accuracy(model_best_epoch, x_test, y_test)
# Out:
# Model with last epoch weights:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-b6d169507ca4> in <module>
#       6 model_best_epoch = get_model_best_epoch(get_new_model(x_train[0].shape))
#       7 print('Model with last epoch weights:')
# ----> 8 get_test_accuracy(model_last_epoch, x_test, y_test)
#       9 print('')
#      10 print('Model with best epoch weights:')
#
# <ipython-input-5-5c371de3d003> in get_test_accuracy(model, x_test, y_test)
#       3 def get_test_accuracy(model, x_test, y_test):
#       4     """Test model classification accuracy"""
# ----> 5     test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
#       6     print('accuracy: {acc:0.3f}'.format(acc=test_acc))
#
# AttributeError: 'NoneType' object has no attribute 'evaluate'

# %% [markdown]
# #### Load, from scratch, a model trained on the EuroSat dataset.
#
# In your workspace, you will find another model trained on the `EuroSAT` dataset in `.h5` format. This model is trained on a larger subset of the EuroSAT dataset and has a more complex architecture. The path to the model is `models/EuroSatNet.h5`. See how its testing accuracy compares to your model!

# %%
#### GRADED CELL ####

# Complete the following functions. 
# Make sure to not change the function name or arguments.

def get_model_eurosatnet():
    """
    This function should return the pretrained EuroSatNet.h5 model.
    """
    model_eurosat = load_model('models/EuroSatNet.h5')
    return model_eurosat

# %%
# Run this cell to print a summary of the EuroSatNet model, along with its validation accuracy.

model_eurosatnet = get_model_eurosatnet()
model_eurosatnet.summary()
get_test_accuracy(model_eurosatnet, x_test, y_test)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 16)        6416
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 32, 32, 16)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 32, 32, 16)        2320
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 32, 32, 16)        6416
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 16, 16, 16)        0
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv_6 (Conv2D)              (None, 16, 16, 16)        6416
# _________________________________________________________________
# pool_3 (MaxPooling2D)        (None, 8, 8, 16)          0
# _________________________________________________________________
# conv_7 (Conv2D)              (None, 8, 8, 16)          2320
# _________________________________________________________________
# conv_8 (Conv2D)              (None, 8, 8, 16)          6416
# _________________________________________________________________
# pool_4 (MaxPooling2D)        (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 41,626
# Trainable params: 41,626
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.810

# %% [markdown]
# Congratulations for completing this programming assignment! You're now ready to move on to the capstone project for this course.
